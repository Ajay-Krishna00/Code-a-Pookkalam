# %%
from joy import *
show(circle(r=20)+circle(r=40)+circle(r=60)+circle(r=80)+circle(r=100))
# Out:
# SVG:{self.nodes}

# %%
c1= circle(x=-50, y=0, r=50)
c2= circle(x=50, y=0, r=50)
c3= circle(x=0, y=-50, r=50)
c4= circle(x=0, y=50, r=50)
show (c1,c2,c3,c4)
# Out:
# SVG:{self.nodes}

# %%
from joy import *
c1 = circle(x=0, y=-100, r=50)
c2 = circle(x=0, y=-50, r=100)
c3= circle(x=0, y=0, r=150)
show(c1,c2,c3)
# Out:
# SVG:{self.nodes}

# %% [markdown]
# ## An Eye

# %%
show(circle(r=50)+ellipse(h=100,w=200))
# Out:
# SVG:{self.nodes}

# %% [markdown]
# ### a program to draw the diagonals of a square

# %%
s = rectangle(w=200, h=200)
l1=line(x1=100,y1=100,x2=-100,y2=-100)
l2=line(x1=-100,y1=100,x2=100,y2=-100)
show(s,l2,l1)
# Out:
# SVG:{self.nodes}

# %% [markdown]
# ### Hash

# %%
l1=line(x1=50,y1=100,x2=50,y2=-100)
l2=line(x1=-50,y1=100,x2=-50,y2=-100)
l3=line(x1=-100,y1=50,x2=100,y2=50)
l4=line(x1=-100,y1=-50,x2=100,y2=-50)
show(l1,l2,l3,l4)
# Out:
# SVG:{self.nodes}

# %% [markdown]
# ### Diamond

# %%
from joy import *
p1=point(x=-100,y=0)
p2=point(x=100,y=0)
p3=point(x=0,y=100)
p4=point(x=0,y=-100)
show(polygon([p1,p3,p2,p4]))
# Out:
# SVG:{self.nodes}

# %% [markdown]
# ### Red Black Squares

# %%
sr1=rectangle(h=100,w=100,x=50,y=50,fill='black')
sr2=rectangle(h=100,w=100,x=-50,y=50,fill='red')
sb1=rectangle(h=100,w=100,x=50,y=-50,fill='red')
sb2=rectangle(h=100,w=100,x=-50,y=-50,fill='black')
show(sr1,sr2,sb1,sb2)
# Out:
# SVG:{self.nodes}

# %% [markdown]
# ### Three Overlapping Squares

# %%
s1=rectangle(h=100,w=100,x=50,y=50,fill='blue',stroke='none')
s2=rectangle(h=100,w=100,x=0,y=0,fill='red',stroke='none')
s3=rectangle(h=100,w=100,x=-50,y=-50,fill='green',stroke='none')
show(s3,s2,s1)
# Out:
# SVG:{self.nodes}

# %% [markdown]
# ###  Styled Polygon

# %%
p1=point(x=-100,y=100)
p2=point(x=100,y=100)
p3=point(x=-100,y=-100)
p4=point(x=100,y=-100)
show(polygon([p1,p2,p3,p4],fill='yellow',stroke='red',stroke_width=5))
# Out:
# SVG:{self.nodes}

# %% [markdown]
#  ### The Flag of Italy

# %%
r1=rectangle(h=300,w=100,x=-100,y=0,fill='green',stroke='none')
r2=rectangle(h=300,w=100,x=0,y=0,fill='white',stroke='none')
r3=rectangle(h=300,w=100,x=100,y=0,fill='red',stroke='none')
show(r1,r2,r3)
# Out:
# SVG:{self.nodes}

# %% [markdown]
# ### Three Concentric Circles with Transparency

# %%
f=color(r=250,g=0,b=0,a=0.5)
show(circle(r=50,fill=f,stroke='none')+circle(r=100,fill=f,stroke='none')+circle(r=150,fill=f,stroke='none'))
# Out:
# SVG:{self.nodes}

# %%
W=50
c=rectangle(h=W,w=W) | repeat(4,scale(2))
show(c)
# Out:
# SVG:{self.nodes}

# %%
e1=ellipse(h=200,w=100)
e2= e1 | rotate(45)
e3= e1 | rotate(90)
e4= e1 | rotate(135)
sh=combine([e1,e2,e3,e4])
show(sh)
# Out:
# SVG:{self.nodes}

# %%
c1=circle(r=20,x=50,y=50) | repeat(40,rotate(10))
show(c1)
# Out:
# SVG:{self.nodes}

# %%
c1=circle(r=50,x=0,y=50)
c2=c1 | rotate(120)
c3=c1|rotate(240)
show(c1,c2,c3)
# Out:
# SVG:{self.nodes}

# %%
s1 = ellipse(x=75, y=0, w=150, h=75)
s2=s1|scale(.7)
s3=s1|scale(.3)
show(s1,s2,s3)
# Out:
# SVG:{self.nodes}

# %%
s1 = circle(x=-50, y=100, r=50) + circle(x=-15, y=30, r=30)
2
show(s1)
s2 = s1 | scale(x=-1)
show(s2)
s3 = s1 | scale(x=-1, y=-1)
show(s3)
# Out:
# SVG:{self.nodes}
# SVG:{self.nodes}
# SVG:{self.nodes}

# %%
r=rectangle(h=200,w=100) | repeat(30,rotate(10))
show(r)
# Out:
# SVG:{self.nodes}

# %%
r=circle(r=50,y=50) | repeat(15,rotate(30))

c=circle(r=10,y=110) | repeat(40,rotate(10))
show(r,c)
# Out:
# SVG:{self.nodes}

# %%
r=rectangle(h=250,w=250) | repeat(30,rotate(10) | scale(0.9))
show(r)
# Out:
# SVG:{self.nodes}

# %%
r=rectangle(h=250,w=250) | repeat(30,rotate(10) | scale(0.95))
show(r)
# Out:
# SVG:{self.nodes}

# %%
r=rectangle(h=250,w=250) | repeat(50,rotate(5) | scale(0.92))
show(r)
# Out:
# SVG:{self.nodes}

# %%
c=circle(r=50,x=100) | repeat(36*4, rotate(10) | scale(0.97))
show(c)
# Out:
# SVG:{self.nodes}

# %%
e=ellipse(h=250,w=150) | repeat(70,rotate(5)|scale(0.95))
show(e)
# Out:
# SVG:{self.nodes}

# %%
from joy import *
r=rectangle(h=200,w=200,fill='yellow',stroke='orange',stroke_width=3) | repeat(50,rotate(5) | scale(0.92))
c=circle(r=130,fill='white',stroke='',stroke_width=80)
a=rectangle(h=180,w=180,fill='purple',stroke='blue',stroke_width=2) | repeat(30,rotate(10))
ac=combine([r,c])
show(ac,r)
# Out:
# SVG:{self.nodes}
